# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
allPixelV = x_train.flatten()
print(allPixelV.shape)
print(y_train.shape)
# Out:
# (47040000,)
# (60000,)

# %%
NBINS = 51
NCLASSES = 10
plt.hist(allPixelV, bins=NBINS, weights=np.zeros_like(allPixelV) + 1. / allPixelV.shape[0])
plt.hlines(1/NCLASSES, 0, 1, color="orange")
plt.show()
